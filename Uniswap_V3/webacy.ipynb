# %%
import os
import requests
from dotenv import load_dotenv
import sqlite3
import time

# %%
load_dotenv()

API_KEY = os.getenv('WEBACY_API_KEY') # Fetching the Etherscan API key from environment variables

if not API_KEY: 
    raise ValueError('Please set the WEBACY_API_KEY environment variable.')

print(API_KEY)
# Out:
# DdhFEmvHL86b7QqQMXebW9WyYpzlL9OI8kIZUnRC

# %%
address = "0x826b34e62320108a9fa38a080360d693a8a73111"

url = f"https://api.webacy.com/addresses/{address}"

headers = {
    "accept": "application/json",
    "x-api-key": API_KEY
}

response = requests.get(url, headers=headers)

try:
    data = response.json()
except ValueError:
    data = response.text

data
# Out:
# {'count': 1,
#  'medium': 0,
#  'high': 0,
#  'overallRisk': 0,
#  'issues': [{'score': 0,
#    'tags': [{'name': 'Insufficient Transactions',
#      'description': "This wallet has too few transactions to pass Webacy's KYW (Know Your Wallet) criteria.",
#      'type': 'noHistoryRisk',
#      'severity': 0,
#      'key': 'insufficient_wallet_transactions'}],
#    'categories': {'address_characteristics': {'key': 'address_characteristics',
#      'name': 'Spam',
#      'description': "This address may have risk factors related to address age, number of transactions, or balance. It may be newly created, or doesn't sufficiently pass Webacy's KYW (Know Your Wallet) criteria.",
#      'tags': {'insufficient_wallet_transactions': True}}},
#    'riskScore': 'Low Risk'}],
#  'details': {'fund_flows': {'risk': {'ofac': False,
#     'hacker': False,
#     'mixers': False,
#     'drainer': False,
#     'fbi_ic3': False,
#     'tornado': False},
#    'flows': [],
#    'label': 'Uniswap',
#    'accounts': {'0x1111111254EEB25477B68fb85Ed929f73A960582': {'type': 'contract',
#      'label': '1inch',
#      'address': '0x1111111254EEB25477B68fb85Ed929f73A960582',
#      'risk_score': 0,
#      'additional_labels': {'ofac': False,
#       'hacker': False,
#       'mixers': False,
#       'drainer': False,
#       'fbi_ic3': False,
#       'tornado': False}},
#     '0x3fC91A3afd70395Cd496C647d5a6CC9D4B2b7FAD': {'type': 'contract',
#      'label': 'Uniswap',
#      'address': '0x3fC91A3afd70395Cd496C647d5a6CC9D4B2b7FAD',
#      'risk_score': 0,
#      'additional_labels': {'ofac': False,
#       'hacker': False,
#       'mixers': False,
#       'drainer': False,
#       'fbi_ic3': False,
#       'tornado': False}},
#     '0x63dF7c7e3A6E7c2047aAd84Fd5AE81647ae1CfeB': {'type': 'contract',
#      'label': '0x63dF7c7e3A6E7c2047aAd84Fd5AE81647ae1CfeB',
#      'address': '0x63dF7c7e3A6E7c2047aAd84Fd5AE81647ae1CfeB',
#      'risk_score': 0,
#      'additional_labels': {'ofac': False,
#       'hacker': False,
#       'mixers': False,
#       'drainer': False,
#       'fbi_ic3': False,
#       'tornado': False}},
#     '0x68b3465833fb72A70ecDF485E0e4C7bD8665Fc45': {'type': 'contract',
#      'label': 'Uniswap',
#      'address': '0x68b3465833fb72A70ecDF485E0e4C7bD8665Fc45',
#      'risk_score': 0,
#      'additional_labels': {'ofac': False,
#       'hacker': False,
#       'mixers': False,
#       'drainer': False,
#       'fbi_ic3': False,
#       'tornado': False}},
#     '0x6b75d8AF000000e20B7a7DDf000Ba900b4009A80': {'type': 'contract',
#      'label': 'jaredfromsubway (MEV)',
#      'address': '0x6b75d8AF000000e20B7a7DDf000Ba900b4009A80',
#      'risk_score': 0,
#      'additional_labels': {'ofac': False,
#       'hacker': False,
#       'mixers': False,
#       'drainer': False,
#       'fbi_ic3': False,
#       'tornado': False}},
#     '0x74de5d4FCbf63E00296fd95d33236B9794016631': {'type': 'contract',
#      'label': 'MetaMask',
#      'address': '0x74de5d4FCbf63E00296fd95d33236B9794016631',
#      'risk_score': 0,
#      'additional_labels': {'ofac': False,
#       'hacker': False,
#       'mixers': False,
#       'drainer': False,
#       'fbi_ic3': False,
#       'tornado': False}},
#     '0x826b34e62320108A9fa38a080360d693A8a73111': {'type': 'contract',
#      'label': 'Uniswap',
#      'address': '0x826b34e62320108A9fa38a080360d693A8a73111',
#      'risk_score': 0,
#      'additional_labels': {'ofac': False,
#       'hacker': False,
#       'mixers': False,
#       'drainer': False,
#       'fbi_ic3': False,
#       'tornado': False}},
#     '0x99e9fD582a8eC98524317373B53a351520c768a0': {'type': 'eoa',
#      'label': '0x99e9fD582a8eC98524317373B53a351520c768a0',
#      'address': '0x99e9fD582a8eC98524317373B53a351520c768a0',
#      'risk_score': 0,
#      'additional_labels': {'ofac': False,
#       'hacker': False,
#       'mixers': False,
#       'drainer': False,
#       'fbi_ic3': False,
#       'tornado': False}},
#     '0xC36442b4a4522E871399CD717aBDD847Ab11FE88': {'type': 'contract',
#      'label': 'Uniswap',
#      'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#      'risk_score': 0,
#      'additional_labels': {'ofac': False,
#       'hacker': False,
#       'mixers': False,
#       'drainer': False,
#       'fbi_ic3': False,
#       'tornado': False}},
#     '0xD085e10DC21842a7D292f747a5498f33585A432D': {'type': 'eoa',
#      'label': '0xD085e10DC21842a7D292f747a5498f33585A432D',
#      'address': '0xD085e10DC21842a7D292f747a5498f33585A432D',
#      'risk_score': 0,
#      'additional_labels': {'ofac': False,
#       'hacker': False,
#       'mixers': False,
#       'drainer': False,
#       'fbi_ic3': False,
#       'tornado': False}},
#     '0xE37e799D5077682FA0a244D46E5649F71457BD09': {'type': 'contract',
#      'label': '1inch',
#      'address': '0xE37e799D5077682FA0a244D46E5649F71457BD09',
#      'risk_score': 0,
#      'additional_labels': {'ofac': False,
#       'hacker': False,
#       'mixers': False,
#       'drainer': False,
#       'fbi_ic3': False,
#       'tornado': False}},
#     '0xE87294Fc9395b18BafbB4635442E3fBac4006E51': {'type': 'eoa',
#      'label': '0xE87294Fc9395b18BafbB4635442E3fBac4006E51',
#      'address': '0xE87294Fc9395b18BafbB4635442E3fBac4006E51',
#      'risk_score': 0,
#      'additional_labels': {'ofac': False,
#       'hacker': False,
#       'mixers': False,
#       'drainer': False,
#       'fbi_ic3': False,
#       'tornado': False}},
#     '0xF3dE3C0d654FDa23daD170f0f320a92172509127': {'type': 'contract',
#      'label': 'Dex Router (OKX)',
#      'address': '0xF3dE3C0d654FDa23daD170f0f320a92172509127',
#      'risk_score': 0,
#      'additional_labels': {'ofac': False,
#       'hacker': False,
#       'mixers': False,
#       'drainer': False,
#       'fbi_ic3': False,
#       'tornado': False}},
#     '0xb87FD5e86aa509fa9A06401328F22854E372F0D4': {'type': 'eoa',
#      'label': '0xb87FD5e86aa509fa9A06401328F22854E372F0D4',
#      'address': '0xb87FD5e86aa509fa9A06401328F22854E372F0D4',
#      'risk_score': 0,
#      'additional_labels': {'ofac': False,
#       'hacker': False,
#       'mixers': False,
#       'drainer': False,
#       'fbi_ic3': False,
#       'tornado': False}},
#     '0xc17647dF7615254880CB451b2bbd3344D4fc806A': {'type': 'eoa',
#      'label': '0xc17647dF7615254880CB451b2bbd3344D4fc806A',
#      'address': '0xc17647dF7615254880CB451b2bbd3344D4fc806A',
#      'risk_score': 0,
#      'additional_labels': {'ofac': False,
#       'hacker': False,
#       'mixers': False,
#       'drainer': False,
#       'fbi_ic3': False,
#       'tornado': False}},
#     '0xf081470f5C6FBCCF48cC4e5B82Dd926409DcdD67': {'type': 'contract',
#      'label': 'Kyber Network',
#      'address': '0xf081470f5C6FBCCF48cC4e5B82Dd926409DcdD67',
#      'risk_score': 0,
#      'additional_labels': {'ofac': False,
#       'hacker': False,
#       'mixers': False,
#       'drainer': False,
#       'fbi_ic3': False,
#       'tornado': False}}},
#    'fund_flow_risk': {'ofac': False,
#     'hacker': False,
#     'mixers': False,
#     'drainer': False,
#     'fbi_ic3': False,
#     'tornado': False}},
#   'address_info': {'balance': 0,
#    'expiresAt': 1726966083485,
#    'risk_level': 'medium',
#    'time_1st_tx': 1726879683485,
#    'time_verified': 1726879683485,
#    'has_no_balance': True,
#    'transaction_count': 0,
#    'has_no_transactions': True,
#    'ofac_sanctioned': False},
#   'token_risk': {},
#   'token_metadata_risk': {},
#   'marketData': {'market_cap': 0},
#   'buy_sell_taxes': {'has_buy_tax': False, 'has_sell_tax': False}},
#  'isContract': True}
