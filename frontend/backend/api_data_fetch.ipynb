# %%
import os
import requests
from dotenv import load_dotenv

# %%
load_dotenv()
moralis_key = os.getenv("MORALIS_KEY")

if not moralis_key:
    raise ValueError("Please set the MORALIS_KEY environment variable")

print("Moralis API key loaded successfully")
# Out:
# Moralis API key loaded successfully

# %%
url = "https://deep-index.moralis.io/api/v2.2/wallets/0xcB1C1FdE09f811B294172696404e88E658659905/swaps?chain=eth&limit=25&order=DESC"

headers = {
  "Accept": "application/json",
  "X-API-Key": "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJub25jZSI6IjM5ZTFmOTI1LThkZWItNDViOS04MmFjLWJlMGIxMTViNjQ4MSIsIm9yZ0lkIjoiNDc2MDQ1IiwidXNlcklkIjoiNDg5NzQ4IiwidHlwZUlkIjoiNGE1YmFlN2MtYzRiOS00NjkyLWFmMWEtN2FkYjcxMWZhMjIzIiwidHlwZSI6IlBST0pFQ1QiLCJpYXQiOjE3NjA1MjcyOTYsImV4cCI6NDkxNjI4NzI5Nn0.LtYZ6bL--NzHNTsju2yl5brWj7KyWBTqZPB8F-woXXE"
}

response = requests.get(url, headers=headers, timeout=10)
response.raise_for_status()
data = response.json()
data
# Out:
# {'cursor': None,
#  'page': 1,
#  'pageSize': 25,
#  'result': [{'transactionHash': '0x0cb6b0267195263d5a6545e33cd173e36df402b8b655df60ff1bee74001054f3',
#    'transactionIndex': 22,
#    'transactionType': 'sell',
#    'baseQuotePrice': '2700.43075',
#    'entity': None,
#    'entityLogo': None,
#    'blockTimestamp': '2025-02-06T18:27:23.000Z',
#    'blockNumber': 21789250,
#    'subCategory': 'partialSell',
#    'walletAddress': '0xcb1c1fde09f811b294172696404e88e658659905',
#    'walletAddressLabel': 'reubenrjs.eth',
#    'pairAddress': '0x21c67e77068de97969ba93d4aab21826d33ca12bb9f565d8496e8fda8a82ca27',
#    'pairLabel': 'ETH/USDC',
#    'exchangeName': None,
#    'exchangeAddress': '0x000000000004444c5dc75cb358380d2e3de08a90',
#    'exchangeLogo': 'https://entities-logos.s3.us-east-1.amazonaws.com/uniswap.png',
#    'baseToken': '0x0000000000000000000000000000000000000000',
#    'quoteToken': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',
# ...

# %%
url = "https://deep-index.moralis.io/api/v2.2/erc20/0x6982508145454ce325ddbe47a25d4ec3d2311933/swaps?chain=eth&limit=25&order=DESC"

headers = {
  "Accept": "application/json",
  "X-API-Key": "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJub25jZSI6IjM5ZTFmOTI1LThkZWItNDViOS04MmFjLWJlMGIxMTViNjQ4MSIsIm9yZ0lkIjoiNDc2MDQ1IiwidXNlcklkIjoiNDg5NzQ4IiwidHlwZUlkIjoiNGE1YmFlN2MtYzRiOS00NjkyLWFmMWEtN2FkYjcxMWZhMjIzIiwidHlwZSI6IlBST0pFQ1QiLCJpYXQiOjE3NjA1MjcyOTYsImV4cCI6NDkxNjI4NzI5Nn0.LtYZ6bL--NzHNTsju2yl5brWj7KyWBTqZPB8F-woXXE"
}

response = requests.get(url, headers=headers)
response.raise_for_status()
data_token = response.json()
data_token
# Out:
# {'cursor': 'eyJhbGciOiJIUzI1NiJ9.eyJibG9ja051bWJlciI6MjM1OTg3NDQsImJsb2NrVGltZXN0YW1wIjoxNzYwNzIwNDk1MDAwLCJ0cmFuc2FjdGlvbkluZGV4IjoxNTQsImxvZ0luZGV4IjoyNDAsInBhZ2UiOjJ9.31lL_W6LQtcL4uHtRfO12DCaa5AMlYIhm6MHdbAHtZE',
#  'page': 1,
#  'pageSize': 25,
#  'result': [{'transactionHash': '0xd69f1d5cab6752ea40b3a55994dd4fefb125383bc81445d515fa6157043c701c',
#    'transactionIndex': 40,
#    'transactionType': 'buy',
#    'baseQuotePrice': '1.74776162895e-9',
#    'entity': 'LayerZero',
#    'entityLogo': 'https://entities-logos.s3.us-east-1.amazonaws.com/layerzero.png',
#    'blockTimestamp': '2025-10-17T17:55:59.000Z',
#    'blockNumber': 23599010,
#    'subCategory': 'newPosition',
#    'walletAddress': '0xe93685f3bba03016f02bd1828badd6195988d950',
#    'walletAddressLabel': 'LayerZero: Executor',
#    'pairAddress': '0xa43fe16908251ee70ef74718545e4fe6c5ccec9f',
#    'pairLabel': 'PEPE/WETH',
#    'exchangeName': 'Uniswap v2',
# ...

# %%
url = "https://deep-index.moralis.io/api/v2.2/pairs/0xa43fe16908251ee70ef74718545e4fe6c5ccec9f/swaps?chain=eth&limit=25&order=DESC"

headers = {
  "Accept": "application/json",
  "X-API-Key": "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJub25jZSI6IjM5ZTFmOTI1LThkZWItNDViOS04MmFjLWJlMGIxMTViNjQ4MSIsIm9yZ0lkIjoiNDc2MDQ1IiwidXNlcklkIjoiNDg5NzQ4IiwidHlwZUlkIjoiNGE1YmFlN2MtYzRiOS00NjkyLWFmMWEtN2FkYjcxMWZhMjIzIiwidHlwZSI6IlBST0pFQ1QiLCJpYXQiOjE3NjA1MjcyOTYsImV4cCI6NDkxNjI4NzI5Nn0.LtYZ6bL--NzHNTsju2yl5brWj7KyWBTqZPB8F-woXXE"
}

response = requests.get(url, headers=headers)
response.raise_for_status()
data_pair = response.json()
data_pair
# Out:
# {'page': 1,
#  'cursor': 'eyJhbGciOiJIUzI1NiJ9.eyJibG9ja051bWJlciI6MjM1OTg1MTAsImJsb2NrVGltZXN0YW1wIjoxNzYwNzE3Njg3MDAwLCJ0cmFuc2FjdGlvbkluZGV4Ijo2MSwibG9nSW5kZXgiOjEwNiwicGFnZSI6Mn0.7ICHuhqTrjOl6tw4wu4lSZrdC80M8PbEEOoHpvnOIGU',
#  'pageSize': 25,
#  'exchangeAddress': '0x5c69bee701ef814a2b6a3edd4b1652cb9cc5aa6f',
#  'exchangeLogo': 'https://entities-logos.s3.us-east-1.amazonaws.com/uniswap.png',
#  'exchangeName': 'Uniswap v2',
#  'pairAddress': '0xa43fe16908251ee70ef74718545e4fe6c5ccec9f',
#  'pairLabel': 'PEPE/WETH',
#  'baseToken': {'address': '0x6982508145454ce325ddbe47a25d4ec3d2311933',
#   'name': 'Pepe',
#   'symbol': 'PEPE',
#   'logo': 'https://logo.moralis.io/0x1_0x6982508145454ce325ddbe47a25d4ec3d2311933_5c5ee6fce6d19f71c224cba025989229.jpeg',
#   'decimals': '18'},
#  'quoteToken': {'address': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2',
#   'name': 'Wrapped Ether',
#   'symbol': 'WETH',
# ...
